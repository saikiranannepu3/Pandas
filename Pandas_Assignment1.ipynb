# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\user\Downloads\cleaned_all_phones (1).csv")

# %%
data
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.head()
# Out:
#        phone_name   brand           os  inches resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200
# 1        K20 plus      LG  Android 7.0     5.3   720x1280     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2  1080x1920     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5  1080x1920     4100
# 4             P10  Huawei  Android 7.0     5.1  1080x1920     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0        Li-Po        2        2016-09-01      140.0  ...        False
# 1       Li-Ion        2        2016-12-01      140.0  ...         True
# 2       Li-Ion        4        2017-01-01      147.0  ...         True
# 3        Li-Po        4        2017-01-01      165.0  ...         True
# 4       Li-Ion        4        2017-02-01      145.0  ...         True
#
#    video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %%
data.tail()
# Out:
#             phone_name   brand          os  inches resolution  battery  \
# 1507         vivo Y77t    Vivo  Android 13    6.64  1080x2388     5000
# 1508               11x  Realme  Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme  Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme  Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo  Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 1507        Li-Po        8        2023-08-18      190.0  ...         True
# 1508        Li-Po        8        2023-08-23      190.0  ...         True
# 1509        Li-Po       16        2023-08-28      205.0  ...         True
# 1510        Li-Po       24        2023-08-28      205.0  ...         True
# 1511        Li-Po        8        2023-08-31      175.0  ...         True
#
#       video_4K  video_8K  video_30fps  video_60fps  video_120fps  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %% [markdown]
# ### How many unique  mobile brands are there in the data provided?

# %%
d=data["brand"].unique()
d.shape
# Out:
# (13,)

# %% [markdown]
# ### What is the average ram size of all the collected data?

# %% [markdown]
# ### Which phone is having the maximum and minimum battery capacity?

# %%
data.describe()
# Out:
#             inches      battery      ram(GB)    weight(g)  storage(GB)  \
# count  1512.000000  1512.000000  1512.000000  1512.000000  1512.000000
# mean      6.422460  4389.798942     6.683862   187.636243   109.164683
# std       0.477043   784.607022     2.701433    26.200115    74.436484
# min       3.800000  1821.000000     1.000000   130.000000     1.000000
# 25%       6.300000  4000.000000     4.000000   175.000000    64.000000
# 50%       6.500000  4500.000000     8.000000   187.000000   128.000000
# 75%       6.670000  5000.000000     8.000000   197.250000   128.000000
# max      10.400000  7250.000000    24.000000   500.000000   512.000000
#
#         price(USD)
# count  1512.000000
# mean    337.847036
# std     266.740821
# min      40.000000
# 25%     179.997500
# 50%     260.000000
# 75%     400.000000
# max    2300.000000

# %% [markdown]
# ### Which Phone brand is providing the highest and lowest ram?

# %%
data.apply(max,axis=0)
# Out:
# phone_name           vivo iQOO Z7x
# brand                       Xiaomi
# os                          iOS 16
# inches                        10.4
# resolution                900x1600
# battery                       7250
# battery_type                 Li-Po
# ram(GB)                         24
# announcement_date       2023-08-31
# weight(g)                    500.0
# storage(GB)                    512
# video_720p                    True
# video_1080p                   True
# video_4K                      True
# video_8K                      True
# video_30fps                   True
# video_60fps                   True
# video_120fps                  True
# video_240fps                  True
# video_480fps                  True
# video_960fps                  True
# price(USD)                  2300.0
# dtype: object

# %%
data.apply(min,axis=0)
# Out:
# phone_name                    1
# brand                     Apple
# os                      Android
# inches                      3.8
# resolution            1080x1920
# battery                    1821
# battery_type             Li-Ion
# ram(GB)                       1
# announcement_date    2016-09-01
# weight(g)                 130.0
# storage(GB)                   1
# video_720p                False
# video_1080p               False
# video_4K                  False
# video_8K                  False
# video_30fps               False
# video_60fps               False
# video_120fps              False
# video_240fps              False
# video_480fps              False
# video_960fps              False
# price(USD)                 40.0
# dtype: object

# %% [markdown]
# ### How many phones has android 7.0 as there operating system?

# %%
d1=data.loc[data['os']=='Android 7.0']

# %%
d1.shape
# Out:
# (33, 22)

# %%
d1
# Out:
#             phone_name    brand           os  inches resolution  battery  \
# 1             K20 plus       LG  Android 7.0     5.3   720x1280     2700
# 2       P8 Lite (2017)   Huawei  Android 7.0     5.2  1080x1920     3000
# 4                  P10   Huawei  Android 7.0     5.1  1080x1920     3200
# 5           Xperia XA1     Sony  Android 7.0     5.0   720x1280     2300
# 6             P10 Lite   Huawei  Android 7.0     5.2  1080x1920     3000
# 7             P10 Plus   Huawei  Android 7.0     5.5  1440x2560     3750
# 8     Xperia XA1 Ultra     Sony  Android 7.0     6.0  1080x1920     2700
# 9             X power2       LG  Android 7.0     5.5   720x1280     4500
# 13           Xperia L1     Sony  Android 7.0     5.5   720x1280     2620
# 16     Galaxy Xcover 4  Samsung  Android 7.0     5.0   720x1280     2800
# 18          Galaxy S8+  Samsung  Android 7.0     6.2  1440x2960     3500
# 21             Harmony       LG  Android 7.0     5.3   720x1280     2800
# ...

# %% [markdown]
# ### What is the maximum battery capacity provided by Huawei Company?

# %%
d2=data.loc[(data['brand']=='Huawei') & (data['battery']==7000)]

# %%
d2
# Out:
#      phone_name   brand       os  inches resolution  battery battery_type  \
# 1448   nova Y91  Huawei  EMUI 13    6.95  1080x2376     7000        Li-Po
#
#       ram(GB) announcement_date  weight(g)  ...  video_1080p  video_4K  \
# 1448        8        2023-05-23      214.0  ...         True     False
#
#       video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# 1448     False         True        False         False         False
#
#       video_480fps  video_960fps  price(USD)
# 1448         False         False       280.0
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Give the count of phones supporting.

# %% [markdown]
# ##### 4k video 8k video 2k video

# %%
d3=data.loc[data['video_4K']==True]

# %%
d3.shape
# Out:
# (801, 22)

# %%
d4=data.loc[data['video_8K']==True]

# %%
d4.shape
# Out:
# (86, 22)

# %%
d5=data.loc[data['video_1080p']==True]

# %%
d5.shape
# Out:
# (1503, 22)

# %% [markdown]
# ### How many phones supports Li-Po and Li-ion Battery?

# %%
d7=data.loc[(data['battery_type']=='Li-Po') | (data['battery_type']=='Li-Ion')]

# %%
d7
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
d7.shape
# Out:
# (1512, 22)

# %% [markdown]
# ### How many sony phones supports 720x1280 resolution?

# %%
d6=data.loc[(data['brand']=='Sony') & (data['resolution']=='720x1280')]

# %%
d6
# Out:
#             phone_name brand             os  inches resolution  battery  \
# 5           Xperia XA1  Sony    Android 7.0     5.0   720x1280     2300
# 13           Xperia L1  Sony    Android 7.0     5.5   720x1280     2620
# 48  Xperia XZ1 Compact  Sony    Android 8.0     4.6   720x1280     2700
# 66    Xperia R1 (Plus)  Sony    Android 7.1     5.2   720x1280     2620
# 93           Xperia L2  Sony  Android 7.1.1     5.5   720x1280     3300
#
#    battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 5        Li-Ion        3        2017-02-01      143.0  ...         True
# 13       Li-Ion        2        2017-03-01      180.0  ...         True
# 48       Li-Ion        4        2017-08-01      140.0  ...         True
# 66       Li-Ion        3        2017-10-01      154.0  ...         True
# 93       Li-Ion        3        2018-01-01      178.0  ...         True
#
#     video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %%
d6.shape
# Out:
# (5, 22)

# %% [markdown]
# ### Which brand produced maximum number of phone in the given data?

# %%
data['brand'].value_counts().idxmax()
# Out:
# 'Xiaomi'

# %% [markdown]
# ### Which Phone is the oldest?

# %%
pd.to_datetime(data['announcement_date']).iloc[0]
# Out:
# Timestamp('2016-09-01 00:00:00')

# %%
brand=data.sort_values('announcement_date').iloc[0]

# %%
brand
# Out:
# phone_name           Y6II Compact
# brand                      Huawei
# os                    Android 5.1
# inches                        5.0
# resolution               720x1280
# battery                      2200
# battery_type                Li-Po
# ram(GB)                         2
# announcement_date      2016-09-01
# weight(g)                   140.0
# storage(GB)                    16
# video_720p                   True
# video_1080p                 False
# video_4K                    False
# video_8K                    False
# video_30fps                  True
# video_60fps                 False
# video_120fps                False
# video_240fps                False
# video_480fps                False
# video_960fps                False
# price(USD)                  120.0
# Name: 0, dtype: object

# %% [markdown]
# ### Print a pivot table for finding the average weights ,total weights,based on brand and battery type.

# %%
pt=data.pivot_table(values='weight(g)',index=['brand','battery_type'],aggfunc={'weight(g)':['mean','sum']})
pt.columns=['Average Height','Total Weight']

# %%
pt
# Out:
#                       Average Height  Total Weight
# brand   battery_type
# Apple   Li-Ion            186.227273        4097.0
# Google  Li-Ion            190.666667        1144.0
#         Li-Po             176.923077        2300.0
# Honor   Li-Ion            165.333333         496.0
#         Li-Po             190.611570       23064.0
# Huawei  Li-Ion            158.354839        4909.0
#         Li-Po             187.556604       19881.0
# LG      Li-Ion            154.851852        4181.0
#         Li-Po             183.812500        8823.0
# Lenovo  Li-Ion            190.142857        2662.0
#         Li-Po             218.586207        6339.0
# OnePlus Li-Po             191.553191        9003.0
# Oppo    Li-Ion            157.833333        3788.0
#         Li-Po             183.174603       34620.0
# Realme  Li-Ion            166.833333        1001.0
#         Li-Po             189.688742       28643.0
# Samsung Li-Ion            178.531250       17139.0
# ...
